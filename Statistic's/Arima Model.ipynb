# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Generate some sample data
np.random.seed(0)
data = np.random.randn(1000)
index = pd.date_range('2020-01-01', periods=1000)

# Create a pandas Series
ts = pd.Series(data, index=index)

# Plot the time series
ts.plot(figsize=(10, 6))
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Sample Time Series Data')
plt.show()

# Plot ACF and PACF to determine the order of ARIMA model
plot_acf(ts, lags=20)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plot_pacf(ts, lags=20)
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# Fit ARIMA model
order = (1, 1, 1)  # p, d, q
model = ARIMA(ts, order=order)
result = model.fit()

# Summary of the model
print(result.summary())

# Plot residuals
result.plot_diagnostics(figsize=(10, 8))
plt.show()

# Forecast future values
forecast_steps = 50
forecast = result.forecast(steps=forecast_steps)

# Plotting the forecast
plt.figure(figsize=(10, 6))
plt.plot(ts, label='Observed')
plt.plot(forecast, label='Forecast', color='red')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1407.226
# Date:                Fri, 23 Feb 2024   AIC                           2820.452
# Time:                        05:19:36   BIC                           2835.172
# Sample:                    01-01-2020   HQIC                          2826.047
#                          - 09-26-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0323      0.032     -1.006      0.314      -0.095       0.031
# ma.L1         -0.9915      0.006   -173.869      0.000      -1.003      -0.980
# sigma2         0.9755      0.044     21.990      0.000       0.889       1.062
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.25
# Prob(Q):                              0.98   Prob(JB):                         0.88
# Heteroskedasticity (H):               0.98   Skew:                             0.03
# Prob(H) (two-sided):                  0.84   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Fit ARIMA model
order = (1, 1, 1)  # p, d, q
model = ARIMA(ts, order=order)
result = model.fit()

# Forecast future values
forecast_steps = 50
forecast = result.forecast(steps=forecast_steps)

# Print the forecasted values
print("Forecasted values:")
print(forecast)

# Plotting the forecast
plt.figure(figsize=(10, 6))
plt.plot(ts, label='Observed')
plt.plot(forecast, label='Forecast', color='red')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
# Forecasted values:
# 2022-09-27    0.072042
# 2022-09-28    0.058146
# 2022-09-29    0.058595
# 2022-09-30    0.058581
# 2022-10-01    0.058581
# 2022-10-02    0.058581
# 2022-10-03    0.058581
# 2022-10-04    0.058581
# 2022-10-05    0.058581
# 2022-10-06    0.058581
# 2022-10-07    0.058581
# 2022-10-08    0.058581
# 2022-10-09    0.058581
# 2022-10-10    0.058581
# 2022-10-11    0.058581
# 2022-10-12    0.058581
# 2022-10-13    0.058581
# 2022-10-14    0.058581
# 2022-10-15    0.058581
# 2022-10-16    0.058581
# 2022-10-17    0.058581
# 2022-10-18    0.058581
# 2022-10-19    0.058581
# 2022-10-20    0.058581
# 2022-10-21    0.058581
# 2022-10-22    0.058581
# 2022-10-23    0.058581
# 2022-10-24    0.058581
# 2022-10-25    0.058581
# 2022-10-26    0.058581
# 2022-10-27    0.058581
# 2022-10-28    0.058581
# 2022-10-29    0.058581
# 2022-10-30    0.058581
# 2022-10-31    0.058581
# 2022-11-01    0.058581
# 2022-11-02    0.058581
# 2022-11-03    0.058581
# 2022-11-04    0.058581
# 2022-11-05    0.058581
# 2022-11-06    0.058581
# 2022-11-07    0.058581
# 2022-11-08    0.058581
# 2022-11-09    0.058581
# 2022-11-10    0.058581
# 2022-11-11    0.058581
# 2022-11-12    0.058581
# 2022-11-13    0.058581
# 2022-11-14    0.058581
# 2022-11-15    0.058581
# Freq: D, Name: predicted_mean, dtype: float64

# %%
# Get user input for p, d, q values
p = int(input("Enter the value of p (AR): "))
d = int(input("Enter the value of d (Integrated): "))
q = int(input("Enter the value of q (MA): "))

# Fit ARIMA model
order = (p, d, q)
model = ARIMA(ts, order=order)
result = model.fit()

# Forecast future values
forecast_steps = 50
forecast = result.forecast(steps=forecast_steps)

# Print the forecasted values
print("Forecasted values:")
print(forecast)

# Plotting the forecast
plt.figure(figsize=(10, 6))
plt.plot(ts, label='Observed')
plt.plot(forecast, label='Forecast', color='red')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
# Enter the value of p (AR): 2
# Enter the value of d (Integrated): 1
# Enter the value of q (MA): 1
# Forecasted values:
# 2022-09-27    0.058784
# 2022-09-28    0.052252
# 2022-09-29    0.056014
# 2022-09-30    0.055839
# 2022-10-01    0.055876
# 2022-10-02    0.055874
# 2022-10-03    0.055874
# 2022-10-04    0.055874
# 2022-10-05    0.055874
# 2022-10-06    0.055874
# 2022-10-07    0.055874
# 2022-10-08    0.055874
# 2022-10-09    0.055874
# 2022-10-10    0.055874
# 2022-10-11    0.055874
# 2022-10-12    0.055874
# 2022-10-13    0.055874
# 2022-10-14    0.055874
# 2022-10-15    0.055874
# 2022-10-16    0.055874
# 2022-10-17    0.055874
# 2022-10-18    0.055874
# 2022-10-19    0.055874
# 2022-10-20    0.055874
# 2022-10-21    0.055874
# 2022-10-22    0.055874
# 2022-10-23    0.055874
# 2022-10-24    0.055874
# 2022-10-25    0.055874
# 2022-10-26    0.055874
# 2022-10-27    0.055874
# 2022-10-28    0.055874
# 2022-10-29    0.055874
# 2022-10-30    0.055874
# 2022-10-31    0.055874
# 2022-11-01    0.055874
# 2022-11-02    0.055874
# 2022-11-03    0.055874
# 2022-11-04    0.055874
# 2022-11-05    0.055874
# 2022-11-06    0.055874
# 2022-11-07    0.055874
# 2022-11-08    0.055874
# 2022-11-09    0.055874
# 2022-11-10    0.055874
# 2022-11-11    0.055874
# 2022-11-12    0.055874
# 2022-11-13    0.055874
# 2022-11-14    0.055874
# 2022-11-15    0.055874
# Freq: D, Name: predicted_mean, dtype: float64
